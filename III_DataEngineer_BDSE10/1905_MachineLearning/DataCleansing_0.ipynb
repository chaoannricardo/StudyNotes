# %%
import pandas as pd
import numpy as np

# %%
review = pd.read_csv("C:/Users/Student/Google_Drive/BDSE10_Project/CleanDataSets/yelp-recsys-2013/training_review_clean.csv")
review_ml = pd.read_csv("C:/Users/Student/Google_Drive/BDSE10_Project/CleanDataSets/yelp-recsys-2013/training_review_final_2013_ml.csv")
user = pd.read_csv("C:/Users/Student/Google_Drive/BDSE10_Project/CleanDataSets/yelp-recsys-2013/training_user_clean.csv")
checkin = pd.read_csv("C:/Users/Student/Google_Drive/BDSE10_Project/CleanDataSets/yelp-recsys-2013/training_checkin_clean_count.csv")
business_normalized = pd.read_csv("C:/Users/Student/Google_Drive/BDSE10_Project/CleanDataSets/yelp-recsys-2013/training_business_normalized.csv")
business_categories = pd.read_csv("C:/Users/Student/Google_Drive/BDSE10_Project/CleanDataSets/yelp-recsys-2013/training_business_categories.csv")

# %%
print(review_ml.info())
print(checkin.info())
print(business_normalized.info())
print(business_categories.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154910 entries, 0 to 154909
# Data columns (total 16 columns):
# business_id      154910 non-null object
# user_id          154910 non-null object
# funny            154910 non-null int64
# useful           154910 non-null int64
# cool             154910 non-null int64
# review_id        154910 non-null object
# stars            154910 non-null int64
# review_count     154910 non-null int64
# gender           154910 non-null int64
# average_stars    154910 non-null float64
# atmosphere       154910 non-null int64
# food             154910 non-null int64
# service          154910 non-null int64
# price            154910 non-null int64
# place            154910 non-null int64
# overall          154910 non-null float64
# dtypes: float64(2), int64(11), object(3)
# memory usage: 18.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8282 entries, 0 to 8281
# Columns: 208 entries, business_id to weekends
# ...

# %%
final = review_ml.merge(review, left_on='review_id', right_on='review_id', how='left')
final0 = final.merge(user, left_on='user_id_x', right_on='user_id', how='left')
final1 = final0.merge(checkin, left_on='business_id_x', right_on='business_id', how='left')
final2 = final1.merge(business_normalized, left_on='business_id_x', right_on='business_id', how='left')



final3 = final2.merge(business_categories, left_on='business_id_x', right_on='business_id', how='left', validate='many_to_one')
print(final3.info())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-71090926f93a> in <module>
#       6
#       7
# ----> 8 final3 = final2.merge(business_categories, left_on='business_id_x', right_on='business_id', how='left', validate='many_to_one')
#       9 print(final3.info())
#      10
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ...

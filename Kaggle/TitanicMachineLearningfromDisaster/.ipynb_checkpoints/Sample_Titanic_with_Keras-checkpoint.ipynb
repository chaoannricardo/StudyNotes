# %% [markdown]
# # Titanic with Keras

# %%
# Download titanic data

import urllib.request
import os

url = 'http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls'
filepath = 'titanic3.xls'

if not os.path.isfile(filepath):
    result = urllib.request.urlretrieve(url, filepath)
    print('download: ', result)

# %%
# Check Data

import numpy as np
import pandas as pd

all_df = pd.read_excel(filepath)
all_df[:2]
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
cols = ['survived', 'name', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked']
all_df = all_df[cols]
all_df[:2]
# Out:
#    survived                            name  pclass     sex      age  sibsp  \
# 0         1   Allen, Miss. Elisabeth Walton       1  female  29.0000      0
# 1         1  Allison, Master. Hudson Trevor       1    male   0.9167      1
#
#    parch      fare embarked
# 0      0  211.3375        S
# 1      2  151.5500        S

# %%
# Check Null values
all_df.isnull().sum()
# Out:
# survived      0
# name          0
# pclass        0
# sex           0
# age         263
# sibsp         0
# parch         0
# fare          1
# embarked      2
# dtype: int64

# %%
from sklearn import preprocessing

def PreprocessData(raw_df):
    df = all_df.drop(['name'], axis=1)
    age_mean = df['age'].mean()
    df['age'] = df['age'].fillna(age_mean)
    
    fare_mean = df['fare'].mean()
    df['fare'] = df['fare'].fillna(fare_mean)
    
    df['sex'] = df['sex'].map({'female':0, 'male':1}).astype(int)
    x_OneHot_df = pd.get_dummies(data = df, columns=['embarked'])
    
    ndarray = x_OneHot_df.values
    label = ndarray[:,0]
    features = ndarray[:,1:]
    
    minmax_scale = preprocessing.MinMaxScaler(feature_range=(0,1))
    scaledFeatures = minmax_scale.fit_transform(features)
    return scaledFeatures, label

# %%
# Split training testing data

msk = np.random.rand(len(all_df)) < 0.8

train_df = all_df[msk]
test_df = all_df[~msk]

print('total: ', len(all_df),
     'train: ', len(train_df),
     'test: ', len(test_df))
# Out:
# total:  1309 train:  1049 test:  260

# %%
train_features, train_label = PreprocessData(train_df)
test_features, test_label = PreprocessData(test_df)

# %% [markdown]
# # Build Keras Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(units=40, input_dim=9, kernel_initializer='uniform', activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(units=30, input_dim=40, kernel_initializer='uniform', activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 40)                400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                1230
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 1,661
# Trainable params: 1,661
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# compile the model

model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

train_history = model.fit(x=train_features,
                         y=train_label,
                         validation_split=0.1,
                         epochs=200, batch_size=1280, verbose=2)
# Out:
# Train on 1178 samples, validate on 131 samples
# Epoch 1/200
#  - 0s - loss: 0.4320 - accuracy: 0.8149 - val_loss: 0.4034 - val_accuracy: 0.8473
# Epoch 2/200
#  - 0s - loss: 0.4150 - accuracy: 0.8226 - val_loss: 0.4029 - val_accuracy: 0.8473
# Epoch 3/200
#  - 0s - loss: 0.4230 - accuracy: 0.8149 - val_loss: 0.4029 - val_accuracy: 0.8473
# Epoch 4/200
#  - 0s - loss: 0.4222 - accuracy: 0.8141 - val_loss: 0.4030 - val_accuracy: 0.8473
# Epoch 5/200
#  - 0s - loss: 0.4277 - accuracy: 0.8226 - val_loss: 0.4029 - val_accuracy: 0.8397
# Epoch 6/200
#  - 0s - loss: 0.4190 - accuracy: 0.8200 - val_loss: 0.4029 - val_accuracy: 0.8397
# Epoch 7/200
#  - 0s - loss: 0.4252 - accuracy: 0.8217 - val_loss: 0.4029 - val_accuracy: 0.8473
- val_loss: 0.4020 - val_accuracy: 0.8397
# Epoch 168/200
#  - 0s - loss: 0.4147 - accuracy: 0.8209 - val_loss: 0.4021 - val_accuracy: 0.8397
# Epoch 169/200
#  - 0s - loss: 0.4214 - accuracy: 0.8124 - val_loss: 0.4021 - val_accuracy: 0.8397
# Epoch 170/200
#  - 0s - loss: 0.4076 - accuracy: 0.8260 - val_loss: 0.4021 - val_accuracy: 0.8397
# Epoch 171/200
#  - 0s - loss: 0.4263 - accuracy: 0.8209 - val_loss: 0.4020 - val_accuracy: 0.8397
# Epoch 172/200
#  - 0s - loss: 0.4154 - accuracy: 0.8200 - val_loss: 0.4019 - val_accuracy: 0.8397
# Epoch 173/200
#  - 0s - loss: 0.4281 - accuracy: 0.8183 - val_loss: 0.4019 - val_accuracy: 0.8473
# Epoch 174/200
#  - 0s - loss: 0.4141 - accuracy: 0.8277 - val_loss: 0.4019 - val_accuracy: 0.8473
# Epoch 175/200
#  - 0s - loss: 0.4117 - accuracy: 0.8217 - val_loss: 0.4019 - val_accuracy: 0.8473
# Epoch 176/200
#  - 0s - loss: 0.4146 - accuracy: 0.8209 - val_loss: 0.4019 - val_accuracy: 0.8397
# Epoch 177/200
#  - 0s - loss: 0.4148 - accuracy: 0.8277 - val_loss: 0.4020 - val_accuracy: 0.8397
# Epoch 178/200
#  - 0s - loss: 0.4126 - accuracy: 0.8277 - val_loss: 0.4020 - val_accuracy: 0.8397
# Epoch 179/200
#  - 0s - loss: 0.4206 - accuracy: 0.8243 - val_loss: 0.4021 - val_accuracy: 0.8397
# Epoch 180/200
#  - 0s - loss: 0.4149 - accuracy: 0.8166 - val_loss: 0.4022 - val_accuracy: 0.8397
# Epoch 181/200
#  - 0s - loss: 0.4137 - accuracy: 0.8217 - val_loss: 0.4022 - val_accuracy: 0.8397
# Epoch 182/200
#  - 0s - loss: 0.4049 - accuracy: 0.8251 - val_loss: 0.4021 - val_accuracy: 0.8397
# Epoch 183/200
#  - 0s - loss: 0.4210 - accuracy: 0.8175 - val_loss: 0.4022 - val_accuracy: 0.8397
# Epoch 184/200
#  - 0s - loss: 0.4113 - accuracy: 0.8217 - val_loss: 0.4023 - val_accuracy: 0.8321
# Epoch 185/200
#  - 0s - loss: 0.4179 - accuracy: 0.8260 - val_loss: 0.4024 - val_accuracy: 0.8321
# Epoch 186/200
#  - 0s - loss: 0.4099 - accuracy: 0.8260 - val_loss: 0.4024 - val_accuracy: 0.8397
# Epoch 187/200
#  - 0s - loss: 0.4136 - accuracy: 0.8183 - val_loss: 0.4024 - val_accuracy: 0.8397
# Epoch 188/200
#  - 0s - loss: 0.4257 - accuracy: 0.8166 - val_loss: 0.4025 - val_accuracy: 0.8397
# Epoch 189/200
#  - 0s - loss: 0.4150 - accuracy: 0.8183 - val_loss: 0.4025 - val_accuracy: 0.8397
# Epoch 190/200
#  - 0s - loss: 0.4147 - accuracy: 0.8294 - val_loss: 0.4023 - val_accuracy: 0.8473
# Epoch 191/200
#  - 0s - loss: 0.4191 - accuracy: 0.8260 - val_loss: 0.4021 - val_accuracy: 0.8397
# Epoch 192/200
#  - 0s - loss: 0.4149 - accuracy: 0.8183 - val_loss: 0.4018 - val_accuracy: 0.8397
# Epoch 193/200
#  - 0s - loss: 0.4168 - accuracy: 0.8141 - val_loss: 0.4017 - val_accuracy: 0.8397
# Epoch 194/200
#  - 0s - loss: 0.4151 - accuracy: 0.8200 - val_loss: 0.4017 - val_accuracy: 0.8397
# Epoch 195/200
#  - 0s - loss: 0.4188 - accuracy: 0.8192 - val_loss: 0.4017 - val_accuracy: 0.8397
# Epoch 196/200
#  - 0s - loss: 0.4176 - accuracy: 0.8158 - val_loss: 0.4017 - val_accuracy: 0.8397
# Epoch 197/200
#  - 0s - loss: 0.4153 - accuracy: 0.8260 - val_loss: 0.4017 - val_accuracy: 0.8397
# Epoch 198/200
#  - 0s - loss: 0.4181 - accuracy: 0.8183 - val_loss: 0.4018 - val_accuracy: 0.8397
# Epoch 199/200
#  - 0s - loss: 0.4118 - accuracy: 0.8243 - val_loss: 0.4019 - val_accuracy: 0.8397
# Epoch 200/200
#  - 0s - loss: 0.4184 - accuracy: 0.8132 - val_loss: 0.4020 - val_accuracy: 0.8397

# %%
import matplotlib.pyplot as plt

def show_train_history(train_history, train, validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
show_train_history(train_history, 'accuracy', 'val_accuracy')

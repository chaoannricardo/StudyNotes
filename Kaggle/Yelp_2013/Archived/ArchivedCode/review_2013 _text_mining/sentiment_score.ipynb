# %%
import numpy as np
import pandas as pd 

sentiment_pred = pd.read_csv('sentiment_pred.csv', encoding='ISO-8859-1') 
df = sentiment_pred.rename(columns={'Unnamed: 0': 'relationword'})

# %%
df_word = df.iloc[:,0]
df_sentiment = df.iloc[:,-1]
df_sentiment.columns = ['sentiment']

df = pd.concat([df_word, df_sentiment], axis=1)
df
# Out:
#         relationword  sentiment
# 0             grassy         -1
# 1                hot          1
# 2            rubbery         -1
# 3           chemical         -1
# 4           credible          1
# 5          preferred         -1
# 6        nonexistent         -1
# 7          expansive          1
# 8           ultimate         -1
# 9           positive          1
# 10            rental         -1
# 11         permanent         -1
# 12           luckily         -1
# 13            gluten         -1
# 14          mindless         -1
# 15             wider         -1
# 16      unremarkable         -1
# 17           cooking          1
# 18            tricky         -1
# 19        satisfying          1
# 20          possible          1
# 21             shiny          1
# 22          drenched         -1
# 23          assorted          1
# 24             corse         -1
# 25             least         -1
# 26           fledged          1
# 27          smoother          1
# 28          exciting          1
# 29             funky         -1
# ...              ...        ...
# 2876           tight         -1
# 2877           shake         -1
# 2878          mellow          1
# 2879         service         -1
# 2880       identical         -1
# 2881         certain         -1
# 2882          humble          1
# 2883       beautiful          1
# 2884          easier          1
# 2885             eat         -1
# 2886           gated         -1
# 2887            last         -1
# 2888        buttered         -1
# 2889          beyond         -1
# 2890     forgettable         -1
# 2891         powdery         -1
# 2892           small          1
# 2893         upscale          1
# 2894        catering          1
# 2895           green         -1
# 2896            stir         -1
# 2897          ethnic         -1
# 2898          newest         -1
# 2899           greet         -1
# 2900           fired         -1
# 2901          lowest         -1
# 2902  unprofessional         -1
# 2903          packed         -1
# 2904        military         -1
# 2905          patchy         -1
#
# [2906 rows x 2 columns]

# %%
relation_word = pd.read_csv('relation_word.csv', encoding='ISO-8859-1')
food_word_list = ['lunch','delicious','menu','fresh','breakfast','drink','drinks','tasty','dinner','selection','meal','taste','flavor','dish','food']
atmosphere_word_list = ['atmosphere','happy','fun','friendly']
service_word_list = ['order','ordered','staff','service','wait','server','servered','quality']
price_word_list = ['price','prices']
place_word_list = ['place','places','location','area']

targetword2 = []
for word in relation_word['targetword']:
    if word in food_word_list:
        targetword2.append('food')
    elif word in atmosphere_word_list:
        targetword2.append('atmosphere')
    elif word in service_word_list:
        targetword2.append('service')
    elif word in price_word_list:
        targetword2.append('price')
    elif word in place_word_list:
        targetword2.append('place')
    
len(targetword2)
# Out:
# 193677

# %%
relation_word['targetword'] = pd.DataFrame(targetword2,columns=['targetword'])
relation_word
# Out:
#                    business_id  targetword    relationword  \
# 0       9yKzy9PApeiPPOUJEtnvkg        food      self-serve
# 1       9yKzy9PApeiPPOUJEtnvkg        food      self-serve
# 2       9yKzy9PApeiPPOUJEtnvkg        food          better
# 3       9yKzy9PApeiPPOUJEtnvkg     service           other
# 4       9yKzy9PApeiPPOUJEtnvkg     service         couldnt
# 5       9yKzy9PApeiPPOUJEtnvkg       place          lovely
# 6       9yKzy9PApeiPPOUJEtnvkg       place            many
# 7       ZRJwVLyzEJq1VAihDhYiow        food            nice
# 8       ZRJwVLyzEJq1VAihDhYiow        food         amazing
# 9       ZRJwVLyzEJq1VAihDhYiow        food         italian
# 10      ZRJwVLyzEJq1VAihDhYiow     service           great
# 11      ZRJwVLyzEJq1VAihDhYiow     service           great
# 12      ZRJwVLyzEJq1VAihDhYiow     service           great
# 13      ZRJwVLyzEJq1VAihDhYiow     service        friendly
# 14      ZRJwVLyzEJq1VAihDhYiow     service         overall
# 15      ZRJwVLyzEJq1VAihDhYiow     service             low
# 16      ZRJwVLyzEJq1VAihDhYiow     service             bad
# 17      ZRJwVLyzEJq1VAihDhYiow       place             new
# 18      ZRJwVLyzEJq1VAihDhYiow       place        favorite
# 19      ZRJwVLyzEJq1VAihDhYiow       place           other
# 20      ZRJwVLyzEJq1VAihDhYiow       place            high
# 21      ZRJwVLyzEJq1VAihDhYiow       place             top
# 22      ZRJwVLyzEJq1VAihDhYiow       place         perfect
# 23      6oRAC4uyJCsJl1X0WZpVSA        food           quick
# 24      6oRAC4uyJCsJl1X0WZpVSA        food         amazing
# 25      6oRAC4uyJCsJl1X0WZpVSA        food        prepared
# 26      6oRAC4uyJCsJl1X0WZpVSA        food       delicious
# 27      6oRAC4uyJCsJl1X0WZpVSA        food  middle-eastern
# 28      6oRAC4uyJCsJl1X0WZpVSA        food          better
# 29      6oRAC4uyJCsJl1X0WZpVSA        food   mediterranean
# ...                        ...         ...             ...
# 193647  2ZnCITVa0abGce4gZ6RhIw        food          ethnic
# 193648  kdtreSdAr4WoKAl0M3QykA        food            best
# 193649  kdtreSdAr4WoKAl0M3QykA        food         chinese
# 193650  kdtreSdAr4WoKAl0M3QykA       place           other
# 193651  kdtreSdAr4WoKAl0M3QykA       place         chinese
# 193652  dr3FmOSZ_Iy2WyPnS5ABOA       place           other
# 193653  grk9RANQRR-IZouPFP3kgA        food           large
# 193654  grk9RANQRR-IZouPFP3kgA       place             few
# 193655  grk9RANQRR-IZouPFP3kgA       place           other
# 193656  grk9RANQRR-IZouPFP3kgA       place         popular
# 193657  b5F2WCGUnwfh7z9N2AZ-nw        food       different
# 193658  b5F2WCGUnwfh7z9N2AZ-nw        food            best
# 193659  YsB1NWGekh-4ETJW3vyyWw        food          simple
# 193660  1AR1oHvHVPihkNWNyQ7wtA     service            good
# 193661  y-jTQqdSIZO6tzKYdwpcVA  atmosphere           small
# 193662  y-jTQqdSIZO6tzKYdwpcVA        food            free
# 193663  y-jTQqdSIZO6tzKYdwpcVA       place           small
# 193664  SSW1EqnX2VfRVGtPsd03Hg        food            fast
# 193665  SSW1EqnX2VfRVGtPsd03Hg       place            fast
# 193666  En2GuQV7FoOGHhXX5SMEBg     service           great
# 193667  En2GuQV7FoOGHhXX5SMEBg       place      particular
# 193668  En2GuQV7FoOGHhXX5SMEBg       place             new
# 193669  En2GuQV7FoOGHhXX5SMEBg       place             new
# 193670  En2GuQV7FoOGHhXX5SMEBg       place         seating
# 193671  KWo4geULVPzCirc0Scpcow        food            good
# 193672  KWo4geULVPzCirc0Scpcow     service        friendly
# 193673  1epH2hHsZ2HoSU8ugWWSOw        food           great
# 193674  1epH2hHsZ2HoSU8ugWWSOw       price           cheap
# 193675  ytKoF3d0XQGt5Va8ru0GMQ     service            fast
# 193676  ytKoF3d0XQGt5Va8ru0GMQ     service          better
#
#                             id_targetword
# 0             9yKzy9PApeiPPOUJEtnvkg*food
# 1             9yKzy9PApeiPPOUJEtnvkg*food
# 2             9yKzy9PApeiPPOUJEtnvkg*food
# 3          9yKzy9PApeiPPOUJEtnvkg*service
# 4          9yKzy9PApeiPPOUJEtnvkg*service
# 5            9yKzy9PApeiPPOUJEtnvkg*place
# 6            9yKzy9PApeiPPOUJEtnvkg*place
# 7             ZRJwVLyzEJq1VAihDhYiow*food
# 8             ZRJwVLyzEJq1VAihDhYiow*food
# 9             ZRJwVLyzEJq1VAihDhYiow*food
# 10         ZRJwVLyzEJq1VAihDhYiow*service
# 11         ZRJwVLyzEJq1VAihDhYiow*service
# 12         ZRJwVLyzEJq1VAihDhYiow*service
# 13         ZRJwVLyzEJq1VAihDhYiow*service
# 14         ZRJwVLyzEJq1VAihDhYiow*service
# 15         ZRJwVLyzEJq1VAihDhYiow*service
# 16         ZRJwVLyzEJq1VAihDhYiow*service
# 17           ZRJwVLyzEJq1VAihDhYiow*place
# 18           ZRJwVLyzEJq1VAihDhYiow*place
# 19           ZRJwVLyzEJq1VAihDhYiow*place
# 20           ZRJwVLyzEJq1VAihDhYiow*place
# 21           ZRJwVLyzEJq1VAihDhYiow*place
# 22           ZRJwVLyzEJq1VAihDhYiow*place
# 23            6oRAC4uyJCsJl1X0WZpVSA*food
# 24            6oRAC4uyJCsJl1X0WZpVSA*food
# 25            6oRAC4uyJCsJl1X0WZpVSA*food
# 26            6oRAC4uyJCsJl1X0WZpVSA*food
# 27            6oRAC4uyJCsJl1X0WZpVSA*food
# 28            6oRAC4uyJCsJl1X0WZpVSA*food
# 29            6oRAC4uyJCsJl1X0WZpVSA*food
# ...                                   ...
# 193647        2ZnCITVa0abGce4gZ6RhIw*food
# 193648        kdtreSdAr4WoKAl0M3QykA*food
# 193649        kdtreSdAr4WoKAl0M3QykA*food
# 193650       kdtreSdAr4WoKAl0M3QykA*place
# 193651       kdtreSdAr4WoKAl0M3QykA*place
# 193652       dr3FmOSZ_Iy2WyPnS5ABOA*place
# 193653        grk9RANQRR-IZouPFP3kgA*food
# 193654       grk9RANQRR-IZouPFP3kgA*place
# 193655       grk9RANQRR-IZouPFP3kgA*place
# 193656       grk9RANQRR-IZouPFP3kgA*place
# 193657        b5F2WCGUnwfh7z9N2AZ-nw*food
# 193658        b5F2WCGUnwfh7z9N2AZ-nw*food
# 193659        YsB1NWGekh-4ETJW3vyyWw*food
# 193660     1AR1oHvHVPihkNWNyQ7wtA*service
# 193661  y-jTQqdSIZO6tzKYdwpcVA*atmosphere
# 193662        y-jTQqdSIZO6tzKYdwpcVA*food
# 193663       y-jTQqdSIZO6tzKYdwpcVA*place
# 193664        SSW1EqnX2VfRVGtPsd03Hg*food
# 193665       SSW1EqnX2VfRVGtPsd03Hg*place
# 193666     En2GuQV7FoOGHhXX5SMEBg*service
# 193667       En2GuQV7FoOGHhXX5SMEBg*place
# 193668       En2GuQV7FoOGHhXX5SMEBg*place
# 193669       En2GuQV7FoOGHhXX5SMEBg*place
# 193670       En2GuQV7FoOGHhXX5SMEBg*place
# 193671        KWo4geULVPzCirc0Scpcow*food
# 193672     KWo4geULVPzCirc0Scpcow*service
# 193673        1epH2hHsZ2HoSU8ugWWSOw*food
# 193674       1epH2hHsZ2HoSU8ugWWSOw*price
# 193675     ytKoF3d0XQGt5Va8ru0GMQ*service
# 193676     ytKoF3d0XQGt5Va8ru0GMQ*service
#
# [193677 rows x 4 columns]

# %%
relation_word['id_targetword'] = relation_word['business_id'] + '*' + relation_word['targetword']

# %%
relation_word2 = pd.concat([relation_word.iloc[:,-1:] , relation_word.iloc[:,-2:-1]],axis=1)
relation_word2
# Out:
#                             id_targetword    relationword
# 0             9yKzy9PApeiPPOUJEtnvkg*food      self-serve
# 1             9yKzy9PApeiPPOUJEtnvkg*food      self-serve
# 2             9yKzy9PApeiPPOUJEtnvkg*food          better
# 3          9yKzy9PApeiPPOUJEtnvkg*service           other
# 4          9yKzy9PApeiPPOUJEtnvkg*service         couldnt
# 5            9yKzy9PApeiPPOUJEtnvkg*place          lovely
# 6            9yKzy9PApeiPPOUJEtnvkg*place            many
# 7             ZRJwVLyzEJq1VAihDhYiow*food            nice
# 8             ZRJwVLyzEJq1VAihDhYiow*food         amazing
# 9             ZRJwVLyzEJq1VAihDhYiow*food         italian
# 10         ZRJwVLyzEJq1VAihDhYiow*service           great
# 11         ZRJwVLyzEJq1VAihDhYiow*service           great
# 12         ZRJwVLyzEJq1VAihDhYiow*service           great
# 13         ZRJwVLyzEJq1VAihDhYiow*service        friendly
# 14         ZRJwVLyzEJq1VAihDhYiow*service         overall
# 15         ZRJwVLyzEJq1VAihDhYiow*service             low
# 16         ZRJwVLyzEJq1VAihDhYiow*service             bad
# 17           ZRJwVLyzEJq1VAihDhYiow*place             new
# 18           ZRJwVLyzEJq1VAihDhYiow*place        favorite
# 19           ZRJwVLyzEJq1VAihDhYiow*place           other
# 20           ZRJwVLyzEJq1VAihDhYiow*place            high
# 21           ZRJwVLyzEJq1VAihDhYiow*place             top
# 22           ZRJwVLyzEJq1VAihDhYiow*place         perfect
# 23            6oRAC4uyJCsJl1X0WZpVSA*food           quick
# 24            6oRAC4uyJCsJl1X0WZpVSA*food         amazing
# 25            6oRAC4uyJCsJl1X0WZpVSA*food        prepared
# 26            6oRAC4uyJCsJl1X0WZpVSA*food       delicious
# 27            6oRAC4uyJCsJl1X0WZpVSA*food  middle-eastern
# 28            6oRAC4uyJCsJl1X0WZpVSA*food          better
# 29            6oRAC4uyJCsJl1X0WZpVSA*food   mediterranean
# ...                                   ...             ...
# 193647        2ZnCITVa0abGce4gZ6RhIw*food          ethnic
# 193648        kdtreSdAr4WoKAl0M3QykA*food            best
# 193649        kdtreSdAr4WoKAl0M3QykA*food         chinese
# 193650       kdtreSdAr4WoKAl0M3QykA*place           other
# 193651       kdtreSdAr4WoKAl0M3QykA*place         chinese
# 193652       dr3FmOSZ_Iy2WyPnS5ABOA*place           other
# 193653        grk9RANQRR-IZouPFP3kgA*food           large
# 193654       grk9RANQRR-IZouPFP3kgA*place             few
# 193655       grk9RANQRR-IZouPFP3kgA*place           other
# 193656       grk9RANQRR-IZouPFP3kgA*place         popular
# 193657        b5F2WCGUnwfh7z9N2AZ-nw*food       different
# 193658        b5F2WCGUnwfh7z9N2AZ-nw*food            best
# 193659        YsB1NWGekh-4ETJW3vyyWw*food          simple
# 193660     1AR1oHvHVPihkNWNyQ7wtA*service            good
# 193661  y-jTQqdSIZO6tzKYdwpcVA*atmosphere           small
# 193662        y-jTQqdSIZO6tzKYdwpcVA*food            free
# 193663       y-jTQqdSIZO6tzKYdwpcVA*place           small
# 193664        SSW1EqnX2VfRVGtPsd03Hg*food            fast
# 193665       SSW1EqnX2VfRVGtPsd03Hg*place            fast
# 193666     En2GuQV7FoOGHhXX5SMEBg*service           great
# 193667       En2GuQV7FoOGHhXX5SMEBg*place      particular
# 193668       En2GuQV7FoOGHhXX5SMEBg*place             new
# 193669       En2GuQV7FoOGHhXX5SMEBg*place             new
# 193670       En2GuQV7FoOGHhXX5SMEBg*place         seating
# 193671        KWo4geULVPzCirc0Scpcow*food            good
# 193672     KWo4geULVPzCirc0Scpcow*service        friendly
# 193673        1epH2hHsZ2HoSU8ugWWSOw*food           great
# 193674       1epH2hHsZ2HoSU8ugWWSOw*price           cheap
# 193675     ytKoF3d0XQGt5Va8ru0GMQ*service            fast
# 193676     ytKoF3d0XQGt5Va8ru0GMQ*service          better
#
# [193677 rows x 2 columns]

# %%
merge_df = pd.merge(relation_word2, df, how='outer')
merge_df = merge_df.fillna(0)
merge_df = merge_df.iloc[0:193677,:]
merge_df
# Out:
#                          id_targetword          relationword  sentiment
# 0          9yKzy9PApeiPPOUJEtnvkg*food            self-serve        0.0
# 1          9yKzy9PApeiPPOUJEtnvkg*food            self-serve        0.0
# 2         irVjrnurmB03bTaj9BXofg*place            self-serve        0.0
# 3         Dz7swOgFook-L89Y_M-aQA*place            self-serve        0.0
# 4         P0hUM6uSt5gVr8RA9-0lfQ*place            self-serve        0.0
# 5         irVjrnurmB03bTaj9BXofg*place            self-serve        0.0
# 6         upzSExkcvYMX9dJMgNARXg*place            self-serve        0.0
# 7         jch1dxmn8_O_HdBEyw8wkg*place            self-serve        0.0
# 8         A6uIi5xvOZARZTCjF9KmsQ*place            self-serve        0.0
# 9         jEkaxdgLxUCf4jtUnCPVWg*place            self-serve        0.0
# 10        6xnPUriIYokNaocrKRWMRw*place            self-serve        0.0
# 11        -73hx2hut_2KPcGpCTO5YA*place            self-serve        0.0
# 12        TdNIQQcfslKjkey4-yAlKg*place            self-serve        0.0
# 13        rDiaO12WX_HaoRA_Y9FbJA*place            self-serve        0.0
# 14        cpFmdYXLAFm0vDwqxO7LTA*place            self-serve        0.0
# 15        7yUmKCf7NgS9j9IcFoeLSg*place            self-serve        0.0
# 16         MLcXtnpzygZvQ9BtseLLlw*food            self-serve        0.0
# 17        R7fAXkib9dnkYtFqOv1HDA*place            self-serve        0.0
# 18        LO_PRBWvDpFz-_bkowmXcw*place            self-serve        0.0
# 19         2bdKR3l4o-S1CscLqqnvVw*food            self-serve        0.0
# 20        jEkaxdgLxUCf4jtUnCPVWg*place            self-serve        0.0
# 21         c1yGkETheht_1vjda7G5sA*food            self-serve        0.0
# 22        tqp42quHT1S_tgXQRXBx5w*place            self-serve        0.0
# 23        WfYQE-MZCQb_BOyW7lWh9Q*place            self-serve        0.0
# 24        WfYQE-MZCQb_BOyW7lWh9Q*place            self-serve        0.0
# 25        TdNIQQcfslKjkey4-yAlKg*place            self-serve        0.0
# 26        AryNioF9fxl8RYGiIE7fSA*place            self-serve        0.0
# 27        T35GMi7R4XtJ84W0Y_nDAg*place            self-serve        0.0
# 28        DVSNgV1DQjKteuKWLCiOEQ*place            self-serve        0.0
# 29        FkFjSrQx33Xn3yC-IUNjUQ*place            self-serve        0.0
# ...                                ...                   ...        ...
# 193647  04HakCR6gEeRYNAoKxkppQ*service                wobbly       -1.0
# 193648     QAUDLYNxhHGdUn5YP7au_w*food  chicken-and-mushroom        0.0
# 193649  QAUDLYNxhHGdUn5YP7au_w*service          store-bought        0.0
# 193650     x5Mv61CnZLohZWxfCVCPTQ*food             hand-made        0.0
# 193651  0g_KFvnPIkA8ywTXPPeRCg*service            goopy-like        0.0
# 193652  iKIyUViQL_lY0TEw3iUKQw*service           thoughtless        0.0
# 193653    GIG-c0WT3b5f8CdtkyQ9yw*place         fried-chicken        0.0
# 193654    92WbJ5Zo_9hRCoOstWEo0g*place                   pro       -1.0
# 193655  K8uEjjG15w9k_ZxpQrr4WQ*service                     4        0.0
# 193656     0SQmfh7ppX3HnYx9SxmReA*food          mexican-made        0.0
# 193657     OVFcGSh4Wu-ss8Iq_fIC-Q*food                serves        1.0
# 193658     OVFcGSh4Wu-ss8Iq_fIC-Q*food          sonora-style        0.0
# 193659  lNOk-u3pj5O5C1WGUVIG3A*service              anywhere       -1.0
# 193660     bXXVRau9ySLcZVkjaAOBIw*food      greasyspicymuddy        0.0
# 193661     bXXVRau9ySLcZVkjaAOBIw*food             barbecued       -1.0
# 193662     bqktAhYfTOXp8lNwghu1BQ*food              touching       -1.0
# 193663     bUzq2QFN56xGJote3cKRzw*food                  icey        0.0
# 193664    ZD3Nvl1hKmGPhImhvTRIKQ*place          taco/mexican        0.0
# 193665    6bYrqzWQ2OOYb0I2GofsHQ*place            on-the-fly        0.0
# 193666    hre_4sjNAo9jYE6PfhRuAw*place              hyped-up        0.0
# 193667     ZQdSGPdEGXPbCWrmJSNm-Q*food         bowling-alley        0.0
# 193668     IqRNPvXvbUbxvfgC6cj6gg*food         unchallenging        0.0
# 193669    Ump8m9ONHX9UN3ZO57zfAA*place           frequentest        0.0
# 193670     EJUaeaUcedPJd769_nG1pA*food                 solar       -1.0
# 193671  4GsI6zedtFa2dTqo50w9-w*service              decently        0.0
# 193672     gZ3GVh4aER2q6_UdA6fTKw*food           well-edited        0.0
# 193673  zZFXEqWY_bE6s_f38RhNMw*service               produce        1.0
# 193674    UETunq2HsmwW9pbsSGWZ6g*place            definatley        0.0
# 193675     3Df6ICj0rHROVH4xUlb7Yw*food                  pops       -1.0
# 193676     5cA0fBYsNagnDot1AATykA*food                wowwww        0.0
#
# [193677 rows x 3 columns]

# %%
re = merge_df.groupby(['id_targetword'])
re.get_group('EJUaeaUcedPJd769_nG1pA*food')['sentiment'].sum()
# Out:
# 5.0

# %%
business_id = []
final_output = []
for business in merge_df['id_targetword']:
    business_id.append(business)
    score = re.get_group(business)['sentiment'].sum()
    final_output.append(score)

# %%
df_business_id = pd.DataFrame(business_id, columns=['id_targetword'])

# %%
df_final_output = pd.DataFrame(final_output, columns=['score'])
df_output = pd.concat([df_business_id, df_final_output], axis = 1)
df_output

# %%
df_output = df_output.drop_duplicates()
df_output

# %%
df_1 = df_output['id_targetword'].str.split('*', expand = True)
df_1.columns = ['business_id', 'targetword']
#df_1.to_csv('df_1.csv',encoding='utf-8')

# %%
df_output2 = pd.concat([df_1, df_output['score']],axis=1)
df_output2.head(5)
#len(df_output2)

# %%
list_output_id = df_output2['business_id'].to_list()
list_output_target = df_output2['targetword'].to_list()
list_output_score = df_output2['score'].to_list()
list_word_score = zip(list_output_target, list_output_score)
df_output3 = list(zip(list_output_id, list_word_score))
len(df_output3)
#df_output3

# %%
businessid_df = df_output2['business_id']
noduplicate = businessid_df.drop_duplicates()
len(noduplicate)

# %%
df_output3[0][1][1]
#len(df_output3)

# %%
atmosphere = []
atmosphere_word_list = ['atmosphere','happy','fun','friendly']
for i in range(len(df_output3)):
    if df_output3[i][1][0] in atmosphere_word_list:
        atmosphere.append(int(df_output3[i][1][1]))
    else:
        atmosphere.append(0)
#len(atmosphere)
#len(businessid_df)

df_atmosphere = pd.DataFrame(atmosphere)
df_atmosphere.columns=['atmosphere']
# df_b_id_atmo = pd.DataFrame(b_id_atmo)
# df_b_id_atmo.columns=['(b_id_atmo']

idx = businessid_df.index
df_atmosphere.index = idx

atmosphere_df = pd.concat([businessid_df, df_atmosphere], axis=1)

# %%
food = []
food_word_list = ['lunch','delicious','menu','fresh','breakfast','drink','drinks','tasty','dinner','selection','meal','taste','flavor','dish','food']
for i in range(len(df_output3)):
    if df_output3[i][1][0] in food_word_list:
        food.append(int(df_output3[i][1][1]))
    else:
        food.append(0)
#len(food)

df_food = pd.DataFrame(food)
df_food.columns=['food']
df_food.index = idx

food_df = pd.concat([businessid_df, df_food], axis=1)
len(food_df)

# %%
service = []

service_word_list = ['order','ordered','staff','service','wait','server','servered','quality']
for i in range(len(df_output3)):
    if df_output3[i][1][0] in service_word_list:
        service.append(int(df_output3[i][1][1]))
    else:
        service.append(0)
#len(service)

df_service = pd.DataFrame(service)
df_service.columns=['service']
df_service.index = idx

service_df = pd.concat([businessid_df, df_service], axis=1)
len(service_df)

# %%
price = []

price_word_list = ['price','prices']
for i in range(len(df_output3)):
    if df_output3[i][1][0] in price_word_list:
        price.append(int(df_output3[i][1][1]))
    else:
        price.append(0)
#len(price)

df_price = pd.DataFrame(price)
df_price.columns=['price']
df_price.index = idx

price_df = pd.concat([businessid_df, df_price], axis=1)
len(price_df)

# %%
place = []

place_word_list = ['place','places','location','area']
for i in range(len(df_output3)):
    if df_output3[i][1][0] in place_word_list:
        place.append(int(df_output3[i][1][1]))
    else:
        place.append(0)
#len(place)

df_place = pd.DataFrame(place)
df_place.columns=['place']
df_place.index = idx

place_df = pd.concat([businessid_df, df_place], axis=1)
len(place)

# %%
final = pd.concat([atmosphere_df, food_df['food'], service_df['service'], price_df['price'], place_df['place']], axis=1)
print(final.head())
 
fi = final.groupby('business_id')
final_output = {}
for i in final['business_id']:
    a_score = list(fi.get_group(i).sum())[1:]
    final_output.update({i:a_score})
    
fi.get_group('9yKzy9PApeiPPOUJEtnvkg').sum()

# %%
final_output

# %%
final_T = pd.DataFrame.from_dict(final_output, orient='index', columns=['atmosphere','food','service','price','place'])
noduplicate = pd.DataFrame(noduplicate, columns=['business_id']) 
id2x = noduplicate.index
final_T.index = id2x
final_score = pd.concat([noduplicate,final_T],axis = 1)
final_score

# %%
total_id = pd.read_csv('total_id.csv',encoding='ISO-8859-1')
total_business_id = total_id['business_id']
final_all = pd.merge(total_business_id, final_score, how='outer')
final_all = final_all.fillna(0)
final_all

# %%
final_neg = pd.read_csv('final_neg.csv', encoding='ISO-8859-1')
final_neg['business_id'] = ''
final_neg

# %%
final_all_score = final_all.iloc[:,0:] + final_neg.iloc[:,0:]

final_all_score = final_all_score.drop_duplicates().dropna()

# %%
final_all_score['overall'] = (final_all_score['atmosphere'] + final_all_score['food'] + 
                              final_all_score['service'] + final_all_score['price'] + final_all_score['place'])/5
final_all_score.dropna()
#final_all_score.loc[final_all_score['overall'] == 0]

# %%
final_all_score.to_csv('final.csv', encoding='utf-8')
